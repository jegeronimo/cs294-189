# %% [markdown]
# ## Project B0
#
# In this notebook we provide an interactive tool for students to explore emails from the spam/ham dataset. The email viewer widget allows you to:
#
# - **Browse emails** from both ham (non-spam) and spam categories
# - **Switch between modes** to view either ham or spam emails
# - **Navigate sequentially** through emails using Previous/Next buttons
# - **Load random emails** to get a diverse sample of the dataset
#
# This tool is meant to help you explore the dataset and understand the characteristics of spam and ham emails for your design document.

# %% [markdown]
# ### Import statements

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display, HTML
import os
import random
from pathlib import Path
from utils import load_email_files, EmailViewer

# Ensure widgets are enabled
widgets.Output()
# Out:
# Output()

# %%
# Load email files using utility function
ham_files, spam_files = load_email_files('data/ham', 'data/spam')
print(f"Found {len(ham_files)} ham emails and {len(spam_files)} spam emails")
# Out:
# Found 2971 ham emails and 1200 spam emails

# %%
# Create and display the email viewer widget
email_viewer = EmailViewer(ham_files, spam_files)
email_viewer.display()
